# %% [markdown]
# # Import Bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Leitura dos Dados

# %%
# Importando conjunto de dados
df_loja = pd.read_excel('tabela_estrutura_lojas.xlsx' , engine='openpyxl')

# Verificando dados ausentes e dtype de cada variavel
df_loja.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CODIGO_LOJA        5 non-null      int64
#  1   NOME_SUPERMERCADO  5 non-null      str
# dtypes: int64(1), str(1)
# memory usage: 212.0 bytes

# %%
# Importando conjunto de dados
df_perfil = pd.read_excel('tabela_perfil_clientes.xlsx' , engine='openpyxl')

# Verificando dados ausentes e dtype de cada variavel
df_perfil.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 37294 entries, 0 to 37293
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CODIGO_CLIENTE         37294 non-null  int64
#  1   PERFIL_SUPERMERCADO_A  37294 non-null  str
#  2   PERFIL_SUPERMERCADO_B  37294 non-null  str
# dtypes: int64(1), str(2)
# memory usage: 874.2 KB

# %%
# Importando conjunto de dados
df_vendas = pd.read_excel('tabela_vendas.xlsx' , engine='openpyxl')

# Verificando dados ausentes e dtype de cada variavel
df_vendas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250378 entries, 0 to 250377
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   MES                  250378 non-null  str
#  1   CODIGO_LOJA          250378 non-null  int64
#  2   CODIGO_CUPOM_FISCAL  250378 non-null  int64
#  3   CODIGO_CLIENTE       250378 non-null  int64
#  4   NOME_CATEGORIA       250378 non-null  str
#  5   FATURAMENTO_BRUTO    250378 non-null  float64
#  6   UNIDADES_VENDIDAS    250378 non-null  int64
# dtypes: float64(1), int64(4), str(2)
# memory usage: 13.4 MB

# %% [markdown]
# É possivel verificar que não existe dados nulls nas tabelas e que o types de cada coluna estão compativeis

# %% [markdown]
# ## Joins entre as Bases de Dados

# %%
# Faça o codigo aqui ---- joins entre as tabelas
df = pd.merge(df_loja, df_vendas, on="CODIGO_LOJA", how="outer")
df = pd.merge(df, df_perfil, on="CODIGO_CLIENTE", how="outer")

# %%
# Validação Join
df.head()
# Out:
#    CODIGO_LOJA NOME_SUPERMERCADO      MES  CODIGO_CUPOM_FISCAL  \
# 0          228    SUPERMERCADO A  JANEIRO           9315399330
# 1          228    SUPERMERCADO A  JANEIRO           9315399330
# 2          228    SUPERMERCADO A  JANEIRO           9319156262
# 3          228    SUPERMERCADO A  JANEIRO           9333019496
# 4          228    SUPERMERCADO A  JANEIRO           9333019496
#
#    CODIGO_CLIENTE  NOME_CATEGORIA  FATURAMENTO_BRUTO  UNIDADES_VENDIDAS  \
# 0             148         LIMPEZA              11.99                  1
# 1             148    CESTA BASICA              11.68                  2
# 2             968    CESTA BASICA              17.48                  4
# 3             968  MERCEARIA SECA              22.57                  3
# 4             968         LIMPEZA              31.96                  4
#
#   PERFIL_SUPERMERCADO_A PERFIL_SUPERMERCADO_B
# 0        ALTO POTENCIAL    FUTURO ABANDONADOR
# 1        ALTO POTENCIAL    FUTURO ABANDONADOR
# 2       BAIXO POTENCIAL    FUTURO ABANDONADOR
# 3       BAIXO POTENCIAL    FUTURO ABANDONADOR
# 4       BAIXO POTENCIAL    FUTURO ABANDONADOR

# %%
# Validação Join
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250378 entries, 0 to 250377
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   CODIGO_LOJA            250378 non-null  int64
#  1   NOME_SUPERMERCADO      250378 non-null  str
#  2   MES                    250378 non-null  str
#  3   CODIGO_CUPOM_FISCAL    250378 non-null  int64
#  4   CODIGO_CLIENTE         250378 non-null  int64
#  5   NOME_CATEGORIA         250378 non-null  str
#  6   FATURAMENTO_BRUTO      250378 non-null  float64
#  7   UNIDADES_VENDIDAS      250378 non-null  int64
#  8   PERFIL_SUPERMERCADO_A  250378 non-null  str
#  9   PERFIL_SUPERMERCADO_B  250378 non-null  str
# dtypes: float64(1), int64(4), str(5)
# memory usage: 19.1 MB

# %% [markdown]
# ## Analise e resposta de cada perguntada

# %% [markdown]
# ### 1 – Qual o diagnóstico de crescimento/retração de vendas do grupo varejista no mês de  fevereiro? Qual a rede varejista que puxa o resultado? O Supermercado A ou Supermercado B?

# %%
df_super_a = pd.DataFrame({
    "MES": "FEVEREIRO",
    "NOME_SUPERMERCADO": "SUPERMERCADO_A"
})

inner_super_a = pd.merge(df, df_super_a, on = "NOME_SUPERMERCADO", how = "inner")
inner_super_a
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_super_a = pd.DataFrame({
#       2     "MES": "FEVEREIRO",
#       3     "NOME_SUPERMERCADO": "SUPERMERCADO_A"
#       4 })
#
# File c:\python314\Lib\site-packages\pandas\core\frame.py:769, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     765             )
#     766
#     767         elif isinstance(data, dict):
#     768             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 769             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy)
#     770         elif isinstance(data, ma.MaskedArray):
#     771             from numpy.ma import mrecords
#     772
#
# File c:\python314\Lib\site-packages\pandas\core\internals\construction.py:460, in dict_to_mgr(data, index, columns, dtype, copy)
#     441 if copy:
#     442     # We only need to copy arrays that will not get consolidated, i.e.
#     443     #  only EA arrays
#     444     arrays = [
#     445         (
#     446             x.copy()
#    (...)    457         for x in arrays
#     458     ]
# --> 460 return arrays_to_mgr(arrays, columns, index, dtype=dtype, consolidate=copy)
#
# File c:\python314\Lib\site-packages\pandas\core\internals\construction.py:113, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, consolidate)
#     110 if verify_integrity:
#     111     # figure out the index, if necessary
#     112     if index is None:
# --> 113         index = _extract_index(arrays)
#     114     else:
#     115         index = ensure_index(index)
#
# File c:\python314\Lib\site-packages\pandas\core\internals\construction.py:634, in _extract_index(data)
#     631         raise ValueError("Per-column arrays must each be 1-dimensional")
#     633 if not indexes and not raw_lengths:
# --> 634     raise ValueError("If using all scalar values, you must pass an index")
#     636 if have_series:
#     637     index = union_indexes(indexes)
#
# ValueError: If using all scalar values, you must pass an index

# %%
df_mes = pd.DataFrame{
    "MES": "FEVEREIRO"
}

# %% [markdown]
# Conclusão:

# %% [markdown]
# ### 2 – Quais categorias de produto puxam os resultados nas duas redes entre os meses de janeiro  e fevereiro?

# %% [markdown]
# Conclusão:

# %% [markdown]
# ### 3 – O movimento visto para as duas redes, do ponto de vista de clientes, é puxado por maior/menor fluxo de consumidores em loja, ou por alterações em seus padrões de gasto entre os meses de janeiro e fevereiro?

# %% [markdown]
# Conclusão:

# %% [markdown]
# ### 4 – Com o diagnóstico obtido até aqui, quais recomendações você forneceria aos times de marketing, operações e comercial das redes?

# %% [markdown]
# Conclusão:
